# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.environ["OPENROUTER_API_KEY"] = "OPENROUTER_API_KEY"

# %%
import requests

API_KEY = "OPENROUTER_API_KEY"

url = "https://openrouter.ai/api/v1/chat/completions"

headers = {
    "Authorization": "Bearer " + "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",
    "Content-Type": "application/json"
}

payload = {
    "model": "deepseek/deepseek-v3.2",
    "messages": [
        {
            "role": "user",
            "content": "Hello"
        }
    ]
}

response = requests.post(
    url,
    headers=headers,
    json=payload
)

print("Status:", response.status_code)
print(response.text)
# Out:
# Status: 200
#
#
#
#
# {"id":"gen-1785923459-kNOl1SB9YMqsGhxgV883","object":"chat.completion","created":1785923459,"model":"deepseek/deepseek-v3.2","provider":"AtlasCloud","system_fingerprint":null,"service_tier":null,"choices":[{"index":0,"logprobs":null,"finish_reason":"stop","native_finish_reason":"stop","message":{"role":"assistant","content":"Hello! How can I assist you today? 😊","refusal":null,"reasoning":null}}],"usage":{"prompt_tokens":11,"completion_tokens":11,"total_tokens":22,"cost":0.00000704,"is_byok":false,"prompt_tokens_details":{"cached_tokens":0,"cache_write_tokens":0,"audio_tokens":0,"video_tokens":0},"cost_details":{"upstream_inference_cost":0.00000704,"upstream_inference_prompt_cost":0.00000286,"upstream_inference_completions_cost":0.00000418},"completion_tokens_details":{"reasoning_tokens":0,"image_tokens":0,"audio_tokens":0}}}

# %%
print(response)
# Out:
# <Response [200]>

# %% [markdown]
# **nex-agi/deepseek-v3.1-nex-n1:free**

# %%
import requests
import json

response = requests.post(
  url="https://openrouter.ai/api/v1/chat/completions",
  headers={
    "Authorization": "Bearer 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",
    "Content-Type": "application/json",
    "HTTP-Referer": "<YOUR_SITE_URL>", # Optional. Site URL for rankings on openrouter.ai.
    "X-Title": "<YOUR_SITE_NAME>", # Optional. Site title for rankings on openrouter.ai.
  },
  data=json.dumps({
    "model": "nex-agi/deepseek-v3.1-nex-n1:free",
    "messages": [
      {
        "role": "user",
        "content": "What is the meaning of life?"
      }
    ]
  })
)

# %%
print(response)
# Out:
# <Response [404]>

# %%
print(response.json())           # it not works for longer work
# Out:
# {'error': {'message': 'The free DeepSeek V3.1 Nex N1 period has ended. To continue using this model, please migrate to the paid slug: nex-agi/deepseek-v3.1-nex-n1', 'code': 404}, 'user_id': 'user_3HU0BbGBECnc0IJXMCp7qemWcXl'}

# %% [markdown]
# **x-ai/grok-4.3**

# %%
import requests
import json

API_KEY = "OPENROUTER_API_KEY"

response = requests.post(
    url="https://openrouter.ai/api/v1/chat/completions",

    headers={
        "Authorization": f"Bearer {API_KEY}",
        "Content-Type": "application/json"
    },

    data=json.dumps({

        "model": "x-ai/grok-4.3",

        "max_tokens": 1000,

        "messages": [
            {
                "role": "user",
                "content": "Can you predict future job recession about stock market or jobs?"
            }
        ]
    })
)


print(response.json())
# Out:
# {'id': 'gen-1785924088-5D6BXIEJJuulzZgxWgdr', 'object': 'chat.completion', 'created': 1785924088, 'model': 'x-ai/grok-4.3', 'provider': 'xAI', 'system_fingerprint': None, 'service_tier': 'default', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'native_finish_reason': 'completed', 'message': {'role': 'assistant', 'content': "**No, I cannot predict future recessions, stock market movements, or job market downturns with any reliable accuracy.**\n\nEconomic forecasting is inherently uncertain. Even professional economists, central banks, and sophisticated models frequently miss the timing, severity, or even the occurrence of recessions. Markets and employment are influenced by too many unpredictable variables: geopolitical events, policy changes, technological shifts, consumer behavior, and black swan events.\n\n### What I *can* do instead\nI can summarize **current data and historical patterns** to give context:\n\n- **Leading indicators** often watched include: in
# ...

# %% [markdown]
# **DeepSeek OCR -- POC test with bunch of library (need to work)**

# %%
# !pip uninstall -y torch torchvision torchaudio
# Out:
# Found existing installation: torch 2.11.0+cu128
# Uninstalling torch-2.11.0+cu128:
#   Successfully uninstalled torch-2.11.0+cu128
# Found existing installation: torchvision 0.26.0+cu128
# Uninstalling torchvision-0.26.0+cu128:
#   Successfully uninstalled torchvision-0.26.0+cu128
# Found existing installation: torchaudio 2.11.0+cu128
# Uninstalling torchaudio-2.11.0+cu128:
#   Successfully uninstalled torchaudio-2.11.0+cu128

# %%
# !pip install torch==2.5.1 torchvision==0.20.1 torchaudio==2.5.1
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.4/906.4 MB 728.3 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 121.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 120.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 70.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 37.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 42.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.5 MB/s eta 0:00:00
# ...

# %%
# !pip install transformers==4.46.3 tokenizers==0.20.3 einops addict easydict
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 118.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 110.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 45.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.23.0
#     Uninstalling huggingface_hub-1.23.0:
#       Successfully uninstalled huggingface_hub-1.23.0
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.22.2
#     Uninstalling tokenizers-0.22.2:
#       Successfully uninstalled tokenizers-0.22.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.13.1
#     Uninstalling transformers-5.13.1:
#       Successfully uninstalled transformers-5.13.1
# ...

# %%
# !pip install timm addict easydict einops

# %%
# !nvidia-smi
# Out:
# Wed Aug  5 10:19:21 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8             12W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import torch

print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0))
# Out:
# Torch version: 2.5.1+cu124
# CUDA available: True
# GPU: Tesla T4

# %%
from transformers import AutoModel, AutoTokenizer
import torch
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "0"

model_name = "deepseek-ai/DeepSeek-OCR"

tokenizer = AutoTokenizer.from_pretrained(
    model_name,
    trust_remote_code=True
)

model = AutoModel.from_pretrained(
    model_name,
    trust_remote_code=True,
    use_safetensors=True
)

model = model.eval().cuda().to(torch.bfloat16)

print("Model loaded")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# You are using a model of type deepseek_vl_v2 to instantiate a model of type DeepseekOCR. This is not supported for all configurations of models and can yield errors.

# %%
# !nvidia-smi
# Out:
# Wed Aug  5 10:36:55 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8             16W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !cat /proc/meminfo | grep MemTotal
# Out:
# MemTotal:       13286944 kB

# %%
# !dmesg | tail -20
# Out:
# [ 1429.960229] pgsteal_kswapd 20100395
# [ 1429.963865] pgsteal_direct 24836115
# [ 1429.967502] pgsteal_khugepaged 0
# [ 1429.970893] pgfault 11636270
# [ 1429.973920] pgmajfault 103205
# [ 1429.977051] pgrefill 15177987
# [ 1429.980166] pgactivate 13034079
# [ 1429.983450] pgdeactivate 15164289
# [ 1429.986914] pglazyfree 0
# [ 1429.989595] pglazyfreed 0
# [ 1429.992366] thp_fault_alloc 0
# [ 1429.995483] thp_collapse_alloc 0
# [ 1429.998865] thp_swpout 0
# [ 1430.001550] thp_swpout_fallback 0
# [ 1430.005012] Tasks state (memory values in pages):
# [ 1430.009871] [  pid  ]   uid  tgid total_vm      rss pgtables_bytes swapents oom_score_adj name
# [ 1430.018640] [  53632]     0 53632  7687660  2925029 39120896        0             0 python3
# [ 1430.027185] oom-kill:constraint=CONSTRAINT_MEMCG,nodemask=(null),cpuset=/,mems_allowed=0,oom_memcg=/jupyter-children,task_memcg=/jupyter-children,task=python3,pid=53632,uid=0
# ...

# %%
# !free -h
# Out:
#                total        used        free      shared  buff/cache   available
# Mem:            12Gi       1.5Gi       9.6Gi       3.0Mi       1.5Gi        10Gi
# Swap:             0B          0B          0B

# %%
import torch

print("CUDA Available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# CUDA Available: True
# GPU: Tesla T4

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
image_file = "/content/drive/MyDrive/image 1.jpg"

# %%
prompt = "\n<|grounding|>Convert the document to markdown."

result = model.infer(
    tokenizer,
    prompt=prompt,
    image_file=image_file,
    output_path="/content/output",
    base_size=512,
    image_size=512,
    crop_mode=False,
    save_results=True
)

print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6345/1394300807.py in <cell line: 0>()
#       1 prompt = "\n<|grounding|>Convert the document to markdown."
#       2
# ----> 3 result = model.infer(
#       4     tokenizer,
#       5     prompt=prompt,
#
# NameError: name 'model' is not defined
