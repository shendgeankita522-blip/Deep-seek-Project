# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
from openai import OpenAI

client = OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key="OPENROUTER_API_KEY",
)

completion = client.chat.completions.create(
    model="deepseek/deepseek-r1",
    messages=[
        {
            "role": "user",
            "content": "How can a non-technical learner transition into data science?"
        }
    ],
    max_tokens=512
)

print(completion.choices[0].message.content)
# Out:
# Transitioning from a non-technical background into data science is absolutely achievable! It requires dedication, strategic learning, and leveraging your existing strengths. Here's a roadmap tailored for non-technical learners:
#
# **Phase 1: Mindset Shift & Foundation Building (1-3 Months)**
#
# 1.  **Embrace the Learning Curve:** Accept that it will take time and consistent effort. Be patient with yourself. Your non-technical background (business, humanities, social sciences, etc.) is an *asset* – you bring domain
